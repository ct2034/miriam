# %%
import numpy as np
np.random.seed(42)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc3 as pm
import scipy
import scipy.stats as stats
import scipy.optimize as opt
import statsmodels.api as sm

# %matplotlib inline
plt.style.use('bmh')
# Out:
# 0.5.7+4.gd8d0c23

# %% [markdown]
# __Data__

# %%
x = np.arange(1000)
y = np.random.normal(loc=100, scale=5, size=len(x))
plt.plot(x,y,'.')
plt.figure()
_ = plt.hist(y)

# %%
mu = bayespy.nodes.GaussianARD(10, 1e-6)
tau = bayespy.nodes.Gamma(13, 2)
Y = bayespy.nodes.GaussianARD(mu, tau, plates=(50,))
Q = bayespy.inference.VB(mu, tau, Y)

# %%
def plot(_mu=mu, _tau=tau, _Y=Y):
    bpplt.pdf(_mu, np.linspace(0, 200, num=1000), name=r'\mu')
    plt.figure()
    bpplt.pdf(_tau, np.linspace(.001, 5, num=1000), name=r'\tau')
    plt.figure()
    _ = bpplt.pdf(_Y, np.linspace(0, 200, num=1000), name=r'Y')
plot()

# %%
Y.observe(y[0:50])
print(np.mean(y[0:50]))
Q.update(repeat=2000)
plot()
# Out:
# 98.8726304737
# Iteration 1: loglike=-2.056945e+02 (0.004 seconds)
# Iteration 2: loglike=-2.039266e+02 (0.004 seconds)
# Iteration 3: loglike=-2.039266e+02 (0.004 seconds)
# Converged at iteration 3.

# %%
mu2 = Y
tau2 = bayespy.nodes.Gamma(13, 2)
Y2 = bayespy.nodes.GaussianARD(mu2, tau2)
plot(mu2, tau2, Y2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-133307cc39a1> in <module>()
#       2 tau2 = bayespy.nodes.Gamma(13, 2)
#       3 Y2 = bayespy.nodes.GaussianARD(mu2, tau2)
# ----> 4 plot(mu2, tau2, Y2)
#
# <ipython-input-15-c3e95b7606ce> in plot(_mu, _tau, _Y)
#       4     bpplt.pdf(_tau, np.linspace(.001, 5, num=1000), name=r'\tau')
#       5     plt.figure()
# ----> 6     _ = bpplt.pdf(_Y, np.linspace(0, 200, num=1000), name=r'Y')
#       7 plot()
#
# /usr/lib/python3.5/site-packages/bayespy/plot.py in pdf(Z, x, name, axes, fig, *args, **kwargs)
#     189
#     190     try:
# --> 191         lpdf = Z.logpdf(x)
#     192     except AttributeError:
#     193         lpdf = Z(x)
#
# /usr/lib/python3.5/site-packages/bayespy/inference/vmp/nodes/expfamily.py in logpdf(self, X, mask)
#     474             axis_sum = tuple(range(-len(dims),0))
#     475             # TODO/FIXME: Use einsum here?
# --> 476             Z = Z + np.sum(phi_d * u_d, axis=axis_sum)
#     477             #Z = Z + misc.sum_multiply(phi_d, u_d, axis=axis_sum)
#     478
#
# ValueError: operands could not be broadcast together with shapes (50,) (1000,)

# %%
Y2.observe(y[50:100])

Q2 = bayespy.inference.VB(mu2, tau2, Y2)
Q2.update(repeat=2000)

plot(mu2, tau2, Y2)
